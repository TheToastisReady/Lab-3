# %%
import threading
from threading import Thread
import matplotlib.pyplot as plt
import sys
import numpy as np
import time
% matplotlib inline
limit = 2000;
#a = 0;
def opt1(total):
    Thread(target = opt2(limit)).start()
    awt = total/2;
    colr = np.random.rand(3);
    xy = np.random.rand(2)*100;
    x = xy[0];
    y = xy[1];
    plt.scatter(x, y, color = colr); 

def opt2(total):
    aw = total/2;
    colr = np.random.rand(3);
    xy = np.random.rand(2)*100;
    x = xy[0];
    y = xy[1];
    plt.scatter(x, y, color = colr); 
start_time = time.time()
for a in range(limit):
    if limit > 1000:
        Thread(target = opt1(limit)).start()
    #else:
        #colr = np.random.rand(3);
        #xy = np.random.rand(2)*100;
        #x = xy[0];
        #y = xy[1];
        #plt.scatter(x, y, color = colr); 
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 9.01448392868042 seconds ---

# %%
import matplotlib.pyplot as plt
import sys
import numpy as np
import time
% matplotlib inline
limit = 2000;
#a = 0;
start_time = time.time()
for a in range(limit):
    #sys.stdout.write("\rDoing thing %a" % a);
    #print(int(a/limit*100), "\r% of the way there");
    colr = np.random.rand(3);
    xy = np.random.rand(2)*100;
    x = xy[0];
    y = xy[1];
    plt.scatter(x, y, color = colr);
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 4.481423377990723 seconds ---

# %%
import matplotlib.pyplot as plt
import sys
import numpy as np
import time
% matplotlib inline
limit = 53;
#a = 0;

for a in range(limit):
    #sys.stdout.write("\rDoing thing %a" % a);
    #print(int(a/limit*100), "\r% of the way there");
    colr = np.random.rand(3);
    xy = np.random.rand(2)*100;
    x = xy[0];
    y = xy[1];
    plt.scatter(x, y, color = colr);
